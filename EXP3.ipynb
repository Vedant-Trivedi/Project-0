# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedant-Trivedi/Project-0/blob/main/EXP3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Study Of Tupple
# ##Vedant Trivedi
# ##25070123121

# %%
tpl = (2,"anurag",True)
print(tpl)
tpl = ("apple","orange","kiwi")
print(tpl[1])
# Out:
# (2, 'anurag', True)
# orange

# %%
tpl = ("apple","orange","kiwi")
tpl[1] = "mango"
print(tpl)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-601734522.py in <cell line: 0>()
#       1 tpl = ("apple","orange","kiwi")
# ----> 2 tpl[1] = "mango"
#       3 print(tpl)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ###Elements are not changeable or appendable in tupple

# %%
tpl = ("apple","orange","kiwi","orange","kiwi","orange","kiwi")
print(tpl[1:4])
print(tpl[:3])
print(tpl[2:])
# Out:
# ('orange', 'kiwi', 'orange')
# ('apple', 'orange', 'kiwi')
# ('kiwi', 'orange', 'kiwi', 'orange', 'kiwi')

# %%
tpl3=(10,)*5
print(tpl3)
list1 = ("symbiosis", )*5
print(list1)
# Out:
# (10, 10, 10, 10, 10)
# ('symbiosis', 'symbiosis', 'symbiosis', 'symbiosis', 'symbiosis')

# %%
tpl = ("apple","orange","kiwi")
print("before:",id(tpl1))
tpl1 = ("banana", "mango")
tpl1+= tpl
print(tpl2)
print("after:",id(tpl1))
# Out:
# before: 139952347110784
# ('apple', 'orange', 'kiwi', 'banana', 'mango')
# after: 139952337542720

# %%
tpl = ["apple","orange","kiwi"]
print("before:",id(tpl))
tpl1 = ["banana", "mango"]
tpl+= tpl
print(tpl)
print("after:",id(tpl))
# Out:
# before: 139952338493504
# ['apple', 'orange', 'kiwi', 'apple', 'orange', 'kiwi']
# after: 139952338493504

# %%
marks = (78, 85, 90, 66, 88)
print(f"Maximum marks: {max(marks)}")
print(f"Minimum marks: {min(marks)}")
print(f"Total marks: {sum(marks)}")
print(f"Number of students: {len(marks)}")
print(f"Average marks: {sum(marks) / len(marks)}")
print(f"Marks sorted in ascending order: {sorted(marks)}")
# Out:
# Maximum marks: 90
# Minimum marks: 66
# Total marks: 407
# Number of students: 5
# Average marks: 81.4
# Marks sorted in ascending order: [66, 78, 85, 88, 90]

# %% [markdown]
# ###Q) A student's exam result is stored in a tuple containing three fixed     fields: Subject name, marks obtained, and grade.
# ###Write a Python program to:
# ###Store the exam result using a tuple. Unpack the tuple elements into separate variables. Display the subject, marks, and grade. Check whether the student has scored 75 or more marks and print "Distinction" if the condition is satisfied.

# %%
subject_name = input("Enter subject name: ")
marks_obtained = int(input("Enter marks obtained: "))
grade = input("Enter grade: ")
exam_result = (subject_name, marks_obtained, grade)
print(f"\nSubject: {subject_name}")
print(f"Marks Obtained: {marks_obtained}")
print(f"Grade: {grade}")

if marks_obtained >= 75:
    print("Result: Distinction")
else:
    print("Result: Pass")
# Out:
# Enter subject name: Vedant
# Enter marks obtained: 45
# Enter grade: B
#
# Subject: Vedant
# Marks Obtained: 45
# Grade: B
# Result: Pass

# %% [markdown]
# ##An organization records an employee's daily attendance for a week using a tuple, where:
# ###"P" represents Present, "A" represents Absent.
# ###Write a Python program to:
# ###Store the attendance record in a tuple.
# ###Count and display the total number of present days.
# ###Count and display the total number of absent days.
# ###Check whether the employee was absent at least once during the recorded period and display an appropriate message.

# %%
attendance_input = input("Enter employee's weekly attendance record (e.g., 'PPAPAPA' for Present/Absent): ")
attendance_record = tuple(attendance_input.upper())
print(f"Employee's weekly attendance record: {attendance_record}")
present_days = attendance_record.count('P')
print(f"Total present days: {present_days}")
absent_days = attendance_record.count('A')
print(f"Total absent days: {absent_days}")
if absent_days > 0:
    print("The employee was absent at least once during the week.")
else:
    print("The employee was present every day this week.")
# Out:
# Enter employee's weekly attendance record (e.g., 'PPAPAPA' for Present/Absent): PPPAPPAAA
# Employee's weekly attendance record: ('P', 'P', 'P', 'A', 'P', 'P', 'A', 'A', 'A')
# Total present days: 5
# Total absent days: 4
# Message: The employee was absent at least once during the week.
