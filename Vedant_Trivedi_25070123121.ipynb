# %% [markdown]
# #Exploratory Data Analysis
# ##Basics of Python
# ###Expt 0

# %%
# Vedant Trivedi - 25070123121

# %%
x=2
y = [1,2,5]
z= "vedant"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# vedant
